# %%
from __future__ import absolute_import, division,print_function, unicode_literals
import numpy as np
import tensorflow as tf
from tensorflow import keras as ks
print(tf.__version__)
# Out:
# 2.4.1

# %%
(training_images, training_labels), (test_images, test_labels) = ks.datasets.fashion_mnist.load_data()

# %%
print('Training Images datasets shape: {}'.format(training_images.shape))
print("Training labels shape: ", training_labels.shape)
print("Test images shape: ", test_images.shape)
print("Test labels shape: ", test_labels.shape)
# Out:
# Training Images datasets shape: (60000, 28, 28)
# Training labels shape:  (60000,)
# Test images shape:  (10000, 28, 28)
# test labels shape:  (10000,)

# %% [markdown]
# lets rescale the pixel values between 0 and 1

# %%
training_images = training_images/255
test_images = test_images/255

# %% [markdown]
# we will use keras. With a simple one layer.

# %% [markdown]
# ## Simple neural network

# %%
input_data_shape = (28,28)
hidden_activation_function = 'relu'
output_activation_function = 'softmax'
nn_model = ks.models.Sequential()
nn_model.add(ks.layers.Flatten(input_shape=input_data_shape,name='Input_layer'))
nn_model.add(ks.layers.Dense(32, activation=hidden_activation_function, name='Hidden_layer'))
nn_model.add(ks.layers.Dense(10, activation=output_activation_function, name='Output_layer'))
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_layer (Flatten)        (None, 784)               0
# _________________________________________________________________
# Hidden_layer (Dense)         (None, 32)                25120
# _________________________________________________________________
# Output_layer (Dense)         (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = 'adam'
loss_function = 'sparse_categorical_crossentropy'
metrics = ['accuracy']
nn_model.compile(optimizer=optimizer,loss=loss_function, metrics=metrics)
nn_model.fit(training_images, training_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7037 - accuracy: 0.7626
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4184 - accuracy: 0.8529
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3719 - accuracy: 0.8687
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3484 - accuracy: 0.8751
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3315 - accuracy: 0.8819
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3237 - accuracy: 0.8849
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3132 - accuracy: 0.8873
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2995 - accuracy: 0.8897
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2972 - accuracy: 0.8912
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2841 - accuracy: 0.8950

# %%
training_loss, training_accuracy = nn_model.evaluate(training_images, training_labels)
print('Training data accuracy {}'.format(round(float(training_accuracy),2)))
# Out:
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2890 - accuracy: 0.8946
# Training data accuracy 0.89

# %%
test_loss, test_accuracy = nn_model.evaluate(test_images, test_labels)
print('Test data accuracy {}'.format(round(float(test_accuracy),2)))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3769 - accuracy: 0.8684
# Test data accuracy 0.87

# %% [markdown]
# ## Deep neural network

# %%
input_data_shape = (28,28)
hidden_activation_function = 'relu'
output_activation_function = 'softmax'
dnn_model = ks.models.Sequential()
dnn_model.add(ks.layers.Flatten(input_shape=input_data_shape, name='Input_layer'))
dnn_model.add(ks.layers.Dense(192, activation=hidden_activation_function, name='Hidden_layer_1'))
dnn_model.add(ks.layers.Dense(128, activation=hidden_activation_function, name='Hidden_layer_2'))
dnn_model.add(ks.layers.Dense(10, activation=output_activation_function, name='Output_layer'))
dnn_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_layer (Flatten)        (None, 784)               0
# _________________________________________________________________
# Hidden_layer_1 (Dense)       (None, 192)               150720
# _________________________________________________________________
# Hidden_layer_2 (Dense)       (None, 128)               24704
# _________________________________________________________________
# Output_layer (Dense)         (None, 10)                1290
# =================================================================
# Total params: 176,714
# Trainable params: 176,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = 'adam'
loss_function = 'sparse_categorical_crossentropy'
metric=['accuracy']

dnn_model.compile(optimizer=optimizer, loss=loss_function, metrics=metric)
dnn_model.fit(training_images, training_labels, epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6072 - accuracy: 0.7844
# Epoch 2/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3681 - accuracy: 0.8668
# Epoch 3/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3310 - accuracy: 0.8782
# Epoch 4/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3043 - accuracy: 0.8858
# Epoch 5/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2875 - accuracy: 0.8917
# Epoch 6/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2688 - accuracy: 0.8984
# Epoch 7/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2532 - accuracy: 0.9061
# Epoch 8/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2483 - accuracy: 0.9054
# Epoch 9/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2355 - accuracy: 0.9094
# Epoch 10/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2287 - accuracy: 0.9148
# Epoch 11/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2147 - accuracy: 0.9163
# Epoch 12/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2081 - accuracy: 0.9208
# Epoch 13/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2071 - accuracy: 0.9212
# Epoch 14/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1915 - accuracy: 0.9252
# Epoch 15/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1906 - accuracy: 0.9269
# Epoch 16/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1803 - accuracy: 0.9321
# Epoch 17/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1750 - accuracy: 0.9332
# Epoch 18/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1704 - accuracy: 0.9349
# Epoch 19/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1657 - accuracy: 0.9360
# Epoch 20/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1604 - accuracy: 0.9380

# %%
training_loss, training_accuracy = dnn_model.evaluate(training_images, training_labels)
print('Training data accuracy {}'.format(round(float(training_accuracy),2)))
# Out:
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1635 - accuracy: 0.9366
# Training data accuracy 0.94

# %%
test_loss, test_accuracy = dnn_model.evaluate(test_images, test_labels)
print('Testing data accuracy {}'.format(round(float(test_accuracy),2)))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3741 - accuracy: 0.8844
# Testing data accuracy 0.88
